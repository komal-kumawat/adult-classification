# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv("adult/adult.data")
df1
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
sns.pairplot(df1 )

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2    77516          32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4    13             32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    White          32560 non-null  object
#  9    Male           32560 non-null  object
#  10   2174           32560 non-null  int64
#  11   0              32560 non-null  int64
#  12   40             32560 non-null  int64
#  13   United-States  32560 non-null  object
#  14   <=50K          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df1.describe()
# Out:
#                  39         77516            13          2174             0  \
# count  32560.000000  3.256000e+04  32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05     10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05      2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#                  40
# count  32560.000000
# mean      40.437469
# std       12.347618
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
df1.isnull().sum()
# Out:
# 39                0
#  State-gov        0
#  77516            0
#  Bachelors        0
#  13               0
#  Never-married    0
#  Adm-clerical     0
#  Not-in-family    0
#  White            0
#  Male             0
#  2174             0
#  0                0
#  40               0
#  United-States    0
#  <=50K            0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
sns.histplot(y = df1[' State-gov'])
# Out:
# <Axes: xlabel='Count', ylabel=' State-gov'>

# %%
sns.histplot(y = df1[' Bachelors'])
# Out:
# <Axes: xlabel='Count', ylabel=' Bachelors'>

# %%
sns.histplot(y = df1[' Never-married'])
# Out:
# <Axes: xlabel='Count', ylabel=' Never-married'>

# %%
sns.histplot(y = df1[' Adm-clerical'])
# Out:
# <Axes: xlabel='Count', ylabel=' Adm-clerical'>

# %%
sns.histplot(y = df1[' Not-in-family'])
# Out:
# <Axes: xlabel='Count', ylabel=' Not-in-family'>

# %%
sns.histplot(y = df1[' White'])
# Out:
# <Axes: xlabel='Count', ylabel=' White'>

# %%
sns.histplot(y = df1[' Male'])
# Out:
# <Axes: xlabel='Count', ylabel=' Male'>

# %%
sns.histplot(df1[' United-States'])
# Out:
# <Axes: xlabel=' United-States', ylabel='Count'>

# %%
sns.histplot(y = df1[' <=50K'])
# Out:
# <Axes: xlabel='Count', ylabel=' <=50K'>

# %%
sns.histplot(df1[' 40'])
# Out:
# <Axes: xlabel=' 40', ylabel='Count'>

# %%
# df1.drop([' United-States',' 40'],axis = 1,inplace = True )
# df1.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' <=50K'],
#       dtype='object')

# %%
X = df1.drop(' <=50K',axis = 1)
X = pd.get_dummies(X)
y = df1[' <=50K']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state = 0)

# %%
X_train
# Out:
#        39   77516   13   2174   0   40   State-gov_ ?  \
# 12467  34  117444   13      0   0   65          False
# 15282  54  109413   13      0   0   50          False
# 24869  35  198202    9      0   0   54          False
# 18822  33  190511    4   2176   0   35          False
# 26403  50  138270    9      0   0   40          False
# ...    ..     ...  ...    ...  ..  ...            ...
# 13123  23  181557    9      0   0   25          False
# 19648  19  188864    9      0   0   20          False
# 9845   43  311177   10      0   0   30          False
# 10799  21   39236   10      0   0   50          False
# 2732   49  109705   10      0   0   32          False
#
#         State-gov_ Federal-gov   State-gov_ Local-gov  \
# 12467                    False                  False
# 15282                    False                  False
# 24869                    False                  False
# 18822                    False                  False
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
# Out:
# C:\Users\Anil kumar\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[4655  302]
#  [1011  544]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.82      0.94      0.88      4957
#         >50K       0.64      0.35      0.45      1555
#
#     accuracy                           0.80      6512
#    macro avg       0.73      0.64      0.66      6512
# weighted avg       0.78      0.80      0.78      6512

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7983722358722358
